# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
data=pd.read_excel(r'D:\ramdeobaba assignments\DHLV\TA-1\ta1data.xlsx',index_col=0)

# %%
data.head()
# Out:
#               City                 Date Player_of_Match  \
# Id
# 335982   Bangalore  2008-04-18 00:00:00     BB McCullum
# 335983  Chandigarh  2008-04-19 00:00:00      MEK Hussey
# 335984       Delhi  2008-04-19 00:00:00     MF Maharoof
# 335985      Mumbai  2008-04-20 00:00:00      MV Boucher
# 335986     Kolkata  2008-04-20 00:00:00       DJ Hussey
#
#                                              Venue  Neutral_Venue  \
# Id
# 335982                       M Chinnaswamy Stadium            0.0
# 335983  Punjab Cricket Association Stadium, Mohali            0.0
# 335984                            Feroz Shah Kotla            0.0
# 335985                            Wankhede Stadium            0.0
# 335986                                Eden Gardens            0.0
#
#                               Team1                        Team2  \
# Id
# 335982  Royal Challengers Bangalore        Kolkata Knight Riders
# 335983              Kings XI Punjab          Chennai Super Kings
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 774 entries, 335982 to 1237181
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City             761 non-null    object
#  1   Date             774 non-null    object
#  2   Player_of_Match  770 non-null    object
#  3   Venue            774 non-null    object
#  4   Neutral_Venue    763 non-null    float64
#  5   Team1            765 non-null    object
#  6   Team2            768 non-null    object
#  7   Toss_Winner      774 non-null    object
#  8   Toss_Decision    774 non-null    object
#  9   Winner           770 non-null    object
#  10  Result           770 non-null    object
#  11  Result_Margin    757 non-null    float64
#  12  Eliminator       770 non-null    object
#  13  Method           17 non-null     object
#  14  Umpire1          774 non-null    object
#  15  Umpire2          774 non-null    object
# dtypes: float64(2), object(14)
# ...

# %%
data.describe()
# Out:
#        Neutral_Venue  Result_Margin
# count     763.000000     757.000000
# mean        0.099607      17.492734
# std         0.299671      22.217039
# min         0.000000       1.000000
# 25%         0.000000       6.000000
# 50%         0.000000       8.000000
# 75%         0.000000      20.000000
# max         1.000000     146.000000

# %%
numerical_feature_columns=list(data._get_numeric_data().columns)
numerical_feature_columns
# Out:
# ['Neutral_Venue', 'Result_Margin']

# %%
categorical_feature_columns=list(set(data.columns)-set(data._get_numeric_data().columns))
categorical_feature_columns
# Out:
# ['Winner',
#  'Date',
#  'Eliminator',
#  'Umpire1',
#  'Team2',
#  'Player_of_Match',
#  'Toss_Winner',
#  'Toss_Decision',
#  'Result',
#  'Team1',
#  'Method',
#  'Umpire2',
#  'City',
#  'Venue']

# %%
num_cols=['Neutral_Venue','Result_Margin']
for i in range(0,len(num_cols),2):
    plt.figure(figsize=(10,4))
    plt.subplot(121)
    sns.distplot(data[num_cols[i]],kde=False)
    plt.subplot(122)
    sns.displot(data[num_cols[i+1]],kde=False)
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\lohiy\AppData\Local\Temp\ipykernel_5908\80997768.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[num_cols[i]],kde=False)
# C:\Users\lohiy\AppData\Local\Temp\ipykernel_5908\80997768.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
for i in range(0,len(num_cols),2):
    plt.figure(figsize=(10,4))
    plt.subplot(121)
    sns.distplot(data[num_cols[i]],hist=True,kde=True)
    plt.subplot(122)
    sns.distplot(data[num_cols[i+1]],hist=True,kde=True)
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\lohiy\AppData\Local\Temp\ipykernel_5908\1462426672.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[num_cols[i]],hist=True,kde=True)
# C:\Users\lohiy\AppData\Local\Temp\ipykernel_5908\1462426672.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.countplot(data,y='Venue')
# Out:
# <Axes: xlabel='count', ylabel='Venue'>

# %%
sns.countplot(data,y='City')
# Out:
# <Axes: xlabel='count', ylabel='City'>

# %%
sns.lmplot(data,x='Neutral_Venue',y='Result_Margin',fit_reg=True)

# %%
sns.jointplot(data,x='Neutral_Venue',y='Result_Margin',kind='reg')

# %%
sns.jointplot(data,x='Neutral_Venue',y='Result_Margin',kind='hex')

# %%
cols=['Result_Margin','Neutral_Venue','City','Venue','Team1','Team2','Winner']
sns.pairplot(data[cols])

# %%
plt.figure(figsize=(12,6))
sns.swarmplot(data,x='Neutral_Venue',y='Result_Margin')
# Out:
# C:\Users\lohiy\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 27.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Neutral_Venue', ylabel='Result_Margin'>
# C:\Users\lohiy\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 46.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
